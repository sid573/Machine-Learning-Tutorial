# %%
# Out:
#   File "<ipython-input-4-8dcc86c31e52>", line 3
#     print random.randint(1,101)
#                ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def func(x): return (2**(-1))*np.log(x)

# %%
x= np.random.random(500)
x
# Out:
# array([ 0.13496266,  0.10752699,  0.93221666,  0.74678569,  0.33992877,
#         0.4824661 ,  0.46663081,  0.39307808,  0.38055377,  0.86419357,
#         0.16795018,  0.72021419,  0.67396806,  0.23479483,  0.70172989,
#         0.46448263,  0.26088931,  0.16665107,  0.86609803,  0.11652844,
#         0.27929746,  0.16735397,  0.46987229,  0.92837483,  0.25799842,
#         0.24557219,  0.34801529,  0.6765291 ,  0.94534496,  0.15157645,
#         0.24810845,  0.41836837,  0.71983183,  0.34247448,  0.24127587,
#         0.6787427 ,  0.98913638,  0.95486282,  0.63564979,  0.54752506,
#         0.56964036,  0.83058396,  0.50589393,  0.95323106,  0.26753214,
#         0.70677639,  0.2167178 ,  0.67518914,  0.67051345,  0.25493646,
#         0.75967267,  0.99607877,  0.7395279 ,  0.72991714,  0.11797191,
#         0.11885199,  0.74986323,  0.48047273,  0.20709398,  0.58892386,
#         0.77770414,  0.11050926,  0.6633084 ,  0.02105286,  0.50787002,
# ...

# %%
y=func(x)
y
# Out:
# array([ -1.00137858e+00,  -1.11500672e+00,  -3.50950111e-02,
#         -1.45988517e-01,  -5.39509599e-01,  -3.64422307e-01,
#         -3.81108443e-01,  -4.66873499e-01,  -4.83063895e-01,
#         -7.29792502e-02,  -8.92043933e-01,  -1.64103309e-01,
#         -1.97286279e-01,  -7.24521611e-01,  -1.77103360e-01,
#         -3.83415554e-01,  -6.71829534e-01,  -8.95926539e-01,
#         -7.18785901e-02,  -1.07480994e+00,  -6.37738958e-01,
#         -8.93822070e-01,  -3.77647169e-01,  -3.71598587e-02,
#         -6.77400900e-01,  -7.02082169e-01,  -5.27754429e-01,
#         -1.95389906e-01,  -2.81026928e-02,  -9.43332594e-01,
#         -6.96944664e-01,  -4.35696488e-01,  -1.64368833e-01,
#         -5.35779066e-01,  -7.10907155e-01,  -1.93756583e-01,
#         -5.46152874e-03,  -2.30937975e-02,  -2.26553757e-01,
#         -3.01173520e-01,  -2.81375033e-01,  -9.28131310e-02,
#         -3.40714123e-01,  -2.39489733e-02,  -6.59257776e-01,
# ...

# %%
plt.scatter(x,y,c='blue')
plt.xlabel("X-Values")
plt.ylabel("Y-Values")
plt.show()
